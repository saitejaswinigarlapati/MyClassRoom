# %%
#1a
2+8/2*3
# Out:
# 14.0

# %%
#1b
2+8//2*3
# Out:
# 14

# %%
#1c
(6+3)-8//4*2+3
# Out:
# 8

# %%
9-8//4*2+3
# Out:
# 8

# %%
#1d
2**(2+3)-4/2*2+2
# Out:
# 30.0

# %%
#1e
5<6<8
# Out:
# True

# %%
#1f
5*3>10 and 4+6==11
# Out:
# False

# %%
#1g
x=4
print("ABC"*x)
# Out:
# ABCABCABCABC

# %%
#1h
print(int(2**3/5))
# Out:
# 1

# %%
#1i
x,y=7,2
x,y,x=x+1,y+1,x+10
print(x,y)
# Out:
# 17 3

# %%
#1j
name="Krishna"
age=21
print("Hello",name,"Your age is",age,end="")
print("You will be",age+1,"Next year")
# Out:
# Hello Krishna Your age is 21You will be 22 Next year

# %%
#1k
name="Krishna"
age=21
print("Hello",name,"Your age is",age)
print("You will be",age+1,"Next year")
# Out:
# Hello Krishna Your age is 21
# You will be 22 Next year

# %%
#2a
b=float(input())
h=float(input())
a=(1/2)*(b)*(h**2)
print(a)
# Out:
# 4
# 5
# 50.0

# %%
#2b
import math
x=int(input())
print(math.sqrt(x))
# Out:
# 9
# 3.0

# %%
#2c
import math
r=int(input())
print((2*math.pi)*r)
# Out:
# 5
# 31.41592653589793

# %%
#2d
import math
r=int(input())
print((math.pi)*(r**2))
# Out:
# 5
# 78.53981633974483

# %%
#2e
import math
x1=int(input())
y1=int(input())
x2=int(input())
y2=int(input())
d=((x2-x1)**2+(y2-y1)**2)
print(math.sqrt(d))
# Out:
# 0
# 0
# 1
# 1
# 1.4142135623730951

# %%
#2f
import math
a=3
b=9
c=4
print((-b+math.sqrt((b**2)-(4*a*c)))/(2*a))
# Out:
# -0.5425728922436619

# %%
#3a
q=input("Enter a value:")
print(q)
# Out:
# Enter a value:6
# 6

# %%
#3b
q=input("Enter a value:")
p=input("Enter a value:")
print(q+p)
# Out:
# Enter a value:4
# Enter a value:5
# 45

# %%
#3c
q=input("Enter a value:")
p=input("Enter a value:")
x=int(q)
y=int(p)
print(x+y)
# Out:
# Enter a value:5
# Enter a value:6
# 11

# %%
#3d
name=input("Enter your name:")
age=input("Enter your age")
marks=input("Enter your marks:")
print("The name is:",name)
print("The age is:",age)
print("The marks is:",marks)
# Out:
# Enter your name:sai
# Enter your age15
# Enter your marks:25
# The name is: sai
# The age is: 15
# The marks is: 25

# %%
#4
q=input()
x=int(q)1
print(x+1)
# Out:
# 3
# 4

# %%
#5
a1=int(input())
a2=int(input())
a3=int(input())
a4=int(input())
a5=int(input())
s=a1+a2+a3+a4+a5
print(s)
# Out:
# 1
# 2
# 3
# 4
# 5
# 15

# %%
#6
s1=input()
s2=input()
s3=input()
s4=input()
s5=input()
a=s1+s2+s3+s4+s5
print(a)
# Out:
# 1
# 2
# 3
# 4
# 5
# 12345

# %%
#7
import math
radius=int(input())
A=(math.pi)*(radius**2)
print(A)
# Out:
# 4
# 50.26548245743669

# %%
#8
import math
L=int(input())
A=(math.sqrt(3)/4)*(L**2)
print(A)
# Out:
# 2
# 1.7320508075688772

# %%
#9
principal=int(input("Enter the principal value:"))
rate=float(input("Enter the rate of interest:"))
time=float(input("Enter time period:"))
simple_interest=principal*rate*time/100
print("simple_interest_is:",simple_interest)
# Out:
# Enter the principal value:5
# Enter the rate of interest:1
# Enter time period:3
# simple_interest_is: 0.15

# %%
#10
H=int(input("Enter time in hours:"))
M=int(input("Enter time in minutes:"))
S=int(input("Enter time in secinds:"))
print(H,"hrs:",M,"mins:",S,"sec")
# Out:
# Enter time in hours:2
# Enter time in minutes:4
# Enter time in secinds:6
# 2 hrs: 4 mins: 6 sec

# %%
#11i
#swap the values of 2 variables using third variable
x1=int(input("Enter x1 value:"))
x2=int(input("Enter x2 value:"))
y=x1*x2
print(y/x1)
print(y/x2)
# Out:
# Enter x1 value:2
# Enter x2 value:4
# 4.0
# 2.0

# %%
#11ii
#swap the value without using third variable
x1=int(input("Enter x1 value:"))
x2=int(input("Enter x2 value:"))
x1,x2=x2,x1
print(x1,x2)
# Out:
# Enter x1 value:2
# Enter x2 value:4
# 4 2

# %%
#12
d=int(input("The distance frog jumped:"))
n=int(input(" no of jumps:"))
f=d*n
print("position of froge:",f)
# Out:
# The distance frog jumped:3
#  no of jumps:5
# position of froge: 15

# %%
#13
a=int(input("no of units towors right:"))
b=int(input("no of units towords left:"))
k=int(input("no of jumps:"))
if k%2==0:
    print(k//2*(a-b))
else:
    print(k//2*(a-b)+a)
# Out:
# no of units towors right:5
# no of units towords left:3
# no of jumps:5
# 9
