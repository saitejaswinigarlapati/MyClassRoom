# %%
#1
x=int(input())
if x>99:
  d1=x//100
  d2=x//10%10
  d3=x%10
  print(d1)
  print(d2)
  print(d3)
# Out:
# 123
# 1
# 2
# 3

# %%
#2
x=int(input())
if x>99:
  d1=x%10
  d2=x//10%10
  d3=x//100
  print(d1)
  print(d2)
  print(d3)
# Out:
# 123
# 3
# 2
# 1

# %%
#3
x=int(input())
if x>99:
  d1=x%10
  d2=x//10%10
  d3=x//100
  print(str(d1)+str(d2)+str(d3))
# Out:
# 345
# 543

# %%
x=int(input("Emter the income : "))
y=int(input("Emter age: "))
z=int(input("Emter number of chindrens: "))
if x<10000:
    t=(5/100)*x
if 10001<x<50000:
    t=(10/100)*x
if 50001<x<100000:
    t=(20/100)*x
if x>100000:
    t=(30/100)*x
if y>65:
    t-=500
if z>0:
    t-=z*200
print(f"income tax:{t}")
# Out:
# Emter the income : 200000
# Emter age: 45
# Emter number of chindrens: 2
# income tax:59600.0

# %%
#5
t=int(input())
for i in range(t):
  x=int(input())
  if x+3<=10:
    print("yes")
  else:
     print("no")
# Out:
# 2
# 7
# yes
# 9
# no

# %%
#6
x=int(input())
if x%2==0:
   if x!=0:
    print("yes")
else:
  print("no")
# Out:
# 8
# yes

# %%
#a
a=True
b=False
print("a and b is ", a and b)
print("a or b is ",a or b)
print("not a is ",not a)
# Out:
# a and b is  False
# a or b is  True
# not a is  False

# %% [markdown]
# "and" prints true if both operands are true else prints false
# "or" prints true if one operand is true
# "not" prints opposite to the operand i.e if true it prints false

# %%
#b
a=False and False
print(a)
a=False ==0
print(a)
a=5>6==0
print(a)
# Out:
# False
# True
# False

# %% [markdown]
# false and flase prints flase
# false ==0 so it prints true
# 5>6 i.e false false==0
# hence it prints flase

# %%
#c
a=2
b=3
c=b>5
print("b>5",c)
c=a or b >5
print("a or b>5",c)
c=b>5 or c
print("b>5 or c ",b>5 or c)
c=a and b>5
print("a and b>5 ",a and b>5)
print("a=",a,"b=",b)
# Out:
# b>5 False
# a or b>5 2
# b>5 or c  2
# a and b>5  False
# a= 2 b= 3

# %%
#d
a=2
b=3
c=not 3//2 or 3//2
print(c)
c=not 3//2 and 3//2
print(c)
# Out:
# 1
# False

# %%
#e
a=5>1 and 2==6
print(a)
b=7>4 or 1==5
print(b)
c=not((2>1)or(5==9))
print(c)
d=(True and True)and(True==False)
print(d)
e=(not False)or (not True)
print(e)
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# "and"prints True onlyif both operands are True else it print false
# "or" prints True if any of the operand is True else it prints False
# "not" prints reverse of the operand

# %%
#f
x=5
print(x/0)
#zero division error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 x=5
# ----> 2 print(x/0)
#
# ZeroDivisionError: division by zero

# %%
#g
x=5
print(False and x/0)
print(True and x/0)
#zero division error
# Out:
# False
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 x=5
#       2 print(False and x/0)
# ----> 3 print(True and x/0)
#
# ZeroDivisionError: division by zero

# %%
#h
x=5
print(False or x/0)
print(True or x/0)
#zero division error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 #h
#       2 x=5
# ----> 3 print(False or x/0)
#       4 print(True or x/0)
#
# ZeroDivisionError: division by zero

# %%
#i
a=4+5/7
b=int(4+5/7)
c=4+float(5/7)
d=4+float(5//7)
e=4+float(5)/7
f=4+5.0/7
h=4+5/7.0
i=int(4+5/7.0)
print(a,b,c,d,e,f,g,h,i)
#g is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 9
#       7 h=4+5/7.0
#       8 i=int(4+5/7.0)
# ----> 9 print(a,b,c,d,e,f,g,h,i)
#
# NameError: name 'g' is not defined

# %%
#j
import math
print(-5**2,math.pow(-5,2),-5*5)
# Out:
# -25 25.0 -25

# %%
#k
result1=2**3+(5*4-12)%7//2
print(result1)
result2=2**3+5*4-12%7//2
print(result2)
#in result1 the precedence order is **,(),*,-,%,//,+
#in result2 the precedence order is **,*,%,//,+.-
# Out:
# 8
# 26

# %%
import math
a=math.pow(2,2)
print(a)
# Out:
# 4.0
