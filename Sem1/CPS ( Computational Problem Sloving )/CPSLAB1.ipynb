# %%
print("Amrita Vishwa Vidyapeetham!")
# Out:
# Amrita Vishwa Vidyapeetham!

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
x = 5
y = "Amrita"
print(x)
print(y)
# Out:
# 5
# Amrita

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
x = 10
y = 5
# Addition Operator
z=x+y
print(z)
print('x + y = ', x + y)
x = 10
y = 5
# Subtraction Operator
z=x-y
print(z)
print('x - y = ', x - y)
x = 10
y = 5
# Multiplication Operator
z=x*y
print(z)
print('x * y = ', x * y)
# Out:
# 15
# x + y =  15
# 5
# x - y =  5
# 50
# x * y =  50

# %%
x = 10
y = 5
# Division Operator
print('x / y = ', x / y) # True Division
print('x // y =', x//y) # Class Division
# Out:
# x / y =  2.0
# x // y = 2

# %%
x = 103
y = 5
# Modulus
print('x % y = ', x % y)
x = 100
y = 5
# Modulus
print('x % y = ', x % y)
x = 15
y = 6
# Exponential Operator
print('x ** y = ', x ** y)
# Out:
# x % y =  3
# x % y =  0
# x ** y =  11390625

# %%
import math
x = 4.5467
print (math.ceil(x))
x = 4.1467
print (math.ceil(x))
x = 4
print (math.ceil(x))
x = -4.5467
print(math.ceil(x))
# Out:
# 5
# 5
# 4
# -4

# %%
import math
my_int = 4.5467
print (math.floor(my_int))
my_int = 4.9467
print (math.floor(my_int))
my_int = 4
print (math.floor(my_int))
my_int = -4.5467
print (math.floor(my_int))
# Out:
# 4
# 4
# 4
# -5

# %%
# random integer
integer = -20
print('Absolute value of -20 is:', abs(integer))
#random floating number
floating = -30.33
print('Absolute value of -30.33 is:', abs(floating))
# Out:
# Absolute value of -20 is: 20
# Absolute value of -30.33 is: 30.33

# %%
a = 33
b = 33
if b > a:
 print("b is greater than a")
elif a == b:
 print("a and b are equal")
# Out:
# a and b are equal

# %%
a = 200
b = 33
if b > a:
 print("b is greater than a")
elif a == b:
 print("a and b are equal")
else:
 print("a is greater than b")
# Out:
# a is greater than b

# %%
#population of town
initial_population_in_town=int(input("initial_population_in_town:"))
population_left_town=int(input("populatio_left_town:"))
population_immigrated_to_town=int(input("population_immigrated_to_village:"))
Total_population_of_town=initial_population_in_town-population_left_town+population_immigrated_to_town
print("Total_population_of_town:",Total_population_of_town)
# Out:
# initial_population_in_town:3
# populatio_left_town:2
# population_immigrated_to_village:5
# Total_population_of_town: 6

# %%
#fruit chat
Number_of_apples=int(input("number_of_apples:"))
Number_of_bananas=int(input("number_of_bananas:"))
Number_of_Fruit_chaats=min(Number_of_apples,Number_of_bananas/2)
print("Total number of chaats=",Number_of_Fruit_chaats)
# Out:
# number_of_apples:22
# number_of_bananas:34
# Total number of chaats= 17.0

# %%
#no.of polybags
a=int(input("Enter no of items:"))
if a%10==0:
    print("required number of polybags=",a//10)
else:
    print("required number of polybags=",a//10+1)
# Out:
# Enter no of items:22
# required number of polybags= 3

# %%
#minimum no.of coins
x=int(input('enter total amount : '))
if x%10==0:
    print('minimum no.of coins that chef needs to pay is : ',x//10)
elif x%10!=0 and x%5==0:
    print('minimum no.of coins chef needs to pay is : ',x//10+1)
else:
    print(-1)
# Out:
# enter total amount : 500
# minimum no.of coins that chef needs to pay is :  50
