# %% [markdown]
# ### Machine Learning Demo

# %%
# Create the range of dates here
seven_days = pd.date_range(start='2017-1-1',periods=7)

# Iterate over the dates and print the number and name of the weekday
for day in seven_days:
    print(day.dayofweek, day.day_name())
# Out:
# 6 Sunday
# 0 Monday
# 1 Tuesday
# 2 Wednesday
# 3 Thursday
# 4 Friday
# 5 Saturday

# %%
# pd.Timestamp -> used to represent a single timestamp

import pandas as pd
from datetime import datetime

ts=pd.Timestamp(datetime(2023,5,15))
print(ts)
print(ts.year)
print(ts.day_name())
# Out:
# 2023-05-15 00:00:00
# 2023
# Monday

# %%
# .asfreq() -> Changes the frequence of a timeseries

dates=pd.date_range("2023-01-01",periods=5,freq='D')
ts=pd.Series(range(5),index=dates)
print(ts.index.day_name())
print(ts.asfreq("B")) # Business day frequency
# Out:
# Index(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday'], dtype='object')
# 2023-01-02    1
# 2023-01-03    2
# 2023-01-04    3
# 2023-01-05    4
# Freq: B, dtype: int64
# Index(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday'], dtype='object')

# %%
# pd.Period -> Represents time span (like month ,quarter year)

p=pd.Period("2017-01")
print(p)
print(p.asfreq('D',how='start'))
print(p.asfreq('D',how='end'))
# Out:
# 2017-01
# 2017-01-01
# 2017-01-31

# %%
#pd.date_range() -> Generate a range of dates.
rng = pd.date_range(start="2023-01-01", periods=5, freq="D")
print(rng)
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
# .to_period() -> Convert date index to periods.

dates = pd.date_range("2023-01-01", periods=3, freq="D")
ts = pd.Series([10, 20, 30], index=dates)
print(ts.to_period("M"))   # Convert to monthly periods
# Out:
# 2023-01    10
# 2023-01    20
# 2023-01    30
# Freq: M, dtype: int64

# %%
# pd.to_datetime() -> Convert strings to datetime objects.

dates = ["2023-01-01", "2023-02-01"]
print(pd.to_datetime(dates))
# Out:
# DatetimeIndex(['2023-01-01', '2023-02-01'], dtype='datetime64[ns]', freq=None)

# %%
# .set_index() -> Set datetime as index.

data = {"value": [100, 200, 300]}
df = pd.DataFrame(data, index=pd.to_datetime(["2023-01-01", "2023-01-02", "2023-01-03"]))
print(df)

df = df.set_index(pd.to_datetime(["2023-01-01", "2023-01-02", "2023-01-03"]))
# Out:
#             value
# 2023-01-01    100
# 2023-01-02    200
# 2023-01-03    300

# %%
# .plot() -> Plot time series.
import matplotlib.pyplot as plt

ts = pd.Series(range(10), index=pd.date_range("2023-01-01", periods=10))
ts.plot()
plt.show()

# %%
# .loc[] -> Select values by date.
ts = pd.Series(range(10), index=pd.date_range("2023-01-01", periods=10))
print(ts.loc["2023-01-05"])    # Select single day
print(ts.loc["2023-01-03":"2023-01-06"])  # Select range
# Out:
# 4
# 2023-01-03    2
# 2023-01-04    3
# 2023-01-05    4
# 2023-01-06    5
# Freq: D, dtype: int64

# %%
# .shift() -> Shift values forward/backward in time.
ts = pd.Series([10, 20, 30], index=pd.date_range("2023-01-01", periods=3))
print(ts.shift(1))   # Shift forward
print(ts.shift(-1))  # Shift backward
# Out:
# 2023-01-01     NaN
# 2023-01-02    10.0
# 2023-01-03    20.0
# Freq: D, dtype: float64
# 2023-01-01    20.0
# 2023-01-02    30.0
# 2023-01-03     NaN
# Freq: D, dtype: float64

# %%
# .pct_change() -> Percentage change.

ts = pd.Series([100, 120, 150, 180], index=pd.date_range("2023-01-01", periods=4))
print(ts.pct_change())
# Out:
# 2023-01-01     NaN
# 2023-01-02    0.20
# 2023-01-03    0.25
# 2023-01-04    0.20
# Freq: D, dtype: float64

# %%
# .diff() -> Difference between values.
ts = pd.Series([100, 120, 150, 180], index=pd.date_range("2023-01-01", periods=4))
print(ts.diff())
# Out:
# 2023-01-01     NaN
# 2023-01-02    20.0
# 2023-01-03    30.0
# 2023-01-04    30.0
# Freq: D, dtype: float64

# %%
# pd.read_csv(..., parse_dates=['col'], index_col='col') -> Read CSV with datetime index.

# Example: stock prices
data = pd.read_csv("STOCK_US_XNAS_GOOG.csv", parse_dates=["Date"], index_col="Date")
print(data.head())
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2025-08-29  211.27  215.34  210.97  213.53  24,682,221
# 2025-08-28  207.84  212.90  207.60  212.37  20,915,711
# 2025-08-27  206.46  209.57  206.39  208.21  15,248,980
# 2025-08-26  208.37  208.46  206.45  207.95  23,050,971
# 2025-08-25  207.00  211.09  205.95  209.16  22,788,811

# %% [markdown]
# ### Deep Learning Demo

# %%
#Generating synthetic data (circles)

from sklearn.datasets import make_circles

X,y=make_circles(n_samples=300,noise=0.1,factor=0.5,random_state=0)

# Plot the points with their labels
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdYlGn, edgecolors='k', marker='o', s=50)
plt.xlabel('Feature 1 (X[:, 0])')
plt.ylabel('Feature 2 (X[:, 1])')
plt.title('Plot of Points with Labels (make_circles Dataset)')
plt.colorbar(label='Class Label')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.neural_network import MLPClassifier
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import interactive

# Function to update and display the plot
def update_plot(hidden_layer_size):
# Generate synthetic data (circle)
#X, y = make_circles(n_samples=300, noise=0.1, factor=0.5, random_state=0)

# Create a multi-layer perceptron (MLP) classifier
clf = MLPClassifier(hidden_layer_sizes=(hidden_layer_size,),
activation='relu', max_iter=3000, random_state=1)

# Fit the classifier to the data
clf.fit(X, y)

# Create a grid of points for visualization
#These are 1D arrays of 100 values each, representing the x and y coordinates of the grid.
x_vals=np.linspace(X[:,0].min() -0.1, X[:,0].max() +0.1,100)
y_vals=np.linspace(X[:,1].min() -0.1,X[:,1].max() +0.1, 100)

#The resulting X_plane and Y_plane are both 100x100 arrays,
#representing a grid of 10,000 points.
X_plane, Y_plane = np.meshgrid(x_vals, y_vals)

#grid_points is a single 2D array (grid_points) of shape (10000, 2),
#where each row represents a point in the grid.
grid_points=np.column_stack((X_plane.ravel(), Y_plane.ravel()))

# Predict class labels for the grid points (for decision boundary)
Z= clf.predict(grid_points)

#Z.reshape(X_plane.shape) reshapes Z into a 100×100 array.
Z = Z. reshape(X_plane.shape)

# Predict class labels for the original data points
y_pred=clf.predict(X)

#Clear previous plot
plt.clf()

# Plot the decision boundary
#it is often used to visualize the decision boundary of a model by plotting
#the predicted class probabilities or labels across a grid of points.
plt.contourf(X_plane, Y_plane, Z, levels= -0.5, 0.5, 1.5], cmap=plt.cm.RdYlGn, alpha=0.6)|
I

# Plot the original data points with their predicted labels
# Separate points for each predicted class
class_0 = y_pred == 0 # Indices of points predicted as class @
class_1 = y_pred == 1 # Indices of points predicted as class 1

plt.scatter(X[class_0, 0], X[class_0, 1], c='red', edgecolors='k', marker='o', s=50, label='Predicted Class 0')
plt.scatter(X[class_1, 0], X[class_1, 1], c='green', edgecolors='k', marker='o', s=50, label='Predicted Class 1')

# Add labels and title
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'Decision Boundary and Predicted Labels (Hidden Layer Size=(hidden_layer_size})')
plt. legend( )
plt.show()
# Create a stider for hidden layer size
hidden_layer_size_slider = widgets.IntSlider(valwe=1, min=1, max=10, step=1, description="Hidden Layer Size')

# Create an interactive widget
interactive_plot = interactive(update_plot, hidden_layer_size=hiddem_layer_sire_slider)

# Display the widgets
display(interactive_plot)

Hidden Lay ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.neural_network import MLPClassifier
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import interactive

# Generate synthetic data (circles)
X, y = make_circles(n_samples=300, noise=0.1, factor=0.5, random_state=0)

# Function to update and display the plot
def update_plot(hidden_layer_size):
    # Create a multi-layer perceptron (MLP) classifier
    clf = MLPClassifier(hidden_layer_sizes=(hidden_layer_size,),
                        activation='relu', max_iter=3000, random_state=1)

    # Fit the classifier to the data
    clf.fit(X, y)

    # Create a grid of points for visualization
    x_vals = np.linspace(X[:, 0].min() - 0.1, X[:, 0].max() + 0.1, 100)
    y_vals = np.linspace(X[:, 1].min() - 0.1, X[:, 1].max() + 0.1, 100)
    X_plane, Y_plane = np.meshgrid(x_vals, y_vals)
    grid_points = np.column_stack((X_plane.ravel(), Y_plane.ravel()))

    # Predict class labels for the grid points (for decision boundary)
    Z = clf.predict(grid_points)
    Z = Z.reshape(X_plane.shape)

    # Predict class labels for the original data points
    y_pred = clf.predict(X)

    # Clear previous plot
    plt.clf()

    # Plot the decision boundary
    plt.contourf(X_plane, Y_plane, Z, levels=[-0.5, 0.5, 1.5],
                 cmap=plt.cm.RdYlGn, alpha=0.6)

    # Plot the original data points with their predicted labels
    class_0 = y_pred == 0
    class_1 = y_pred == 1

    plt.scatter(X[class_0, 0], X[class_0, 1], c='red', edgecolors='k',
                marker='o', s=50, label='Predicted Class 0')
    plt.scatter(X[class_1, 0], X[class_1, 1], c='green', edgecolors='k',
                marker='o', s=50, label='Predicted Class 1')

    # Add labels and title
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title(f'Decision Boundary and Predicted Labels (Hidden Layer Size={hidden_layer_size})')
    plt.legend()
    plt.show()

# Create a slider for hidden layer size
hidden_layer_size_slider = widgets.IntSlider(value=1, min=1, max=10, step=1, description="Hidden Layer Size")

# Create an interactive widget
interactive_plot = interactive(update_plot, hidden_layer_size=hidden_layer_size_slider)

# Display the widgets
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=1, description='Hidden Layer Size', max=10, min=1), Output()), _dom_clas…
